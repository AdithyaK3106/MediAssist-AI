# %% [markdown]
# # Naive Bayes Experiment

# %% [markdown]
# ## Experimentation for naive_bayes

# %%
from src.models.classical_ml.predict import ClassicalInferencePipeline
pipeline = ClassicalInferencePipeline(model_name='naive_bayes')
results = pipeline.predict(['I have a headache and fever']) 
print(results)

# %% [markdown]
# ## Model Evaluation

# %%
import json
with open('../../models/classical/naive_bayes/metrics.json', 'r') as f:
    print(json.load(f))
