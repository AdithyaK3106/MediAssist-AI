# %% [markdown]
# # Random Forest Experiment

# %% [markdown]
# ## Experimentation for random_forest

# %%
from src.models.classical_ml.predict import ClassicalInferencePipeline
pipeline = ClassicalInferencePipeline(model_name='random_forest')
results = pipeline.predict(['I have a headache and fever']) 
print(results)

# %% [markdown]
# ## Model Evaluation

# %%
import json
with open('../../models/classical/random_forest/metrics.json', 'r') as f:
    print(json.load(f))
