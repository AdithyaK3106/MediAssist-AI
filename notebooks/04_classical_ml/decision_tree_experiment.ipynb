# %% [markdown]
# # Decision Tree Experiment

# %% [markdown]
# ## Experimentation for decision_tree

# %%
from src.models.classical_ml.predict import ClassicalInferencePipeline
pipeline = ClassicalInferencePipeline(model_name='decision_tree')
results = pipeline.predict(['I have a headache and fever']) 
print(results)

# %% [markdown]
# ## Model Evaluation

# %%
import json
with open('../../models/classical/decision_tree/metrics.json', 'r') as f:
    print(json.load(f))
