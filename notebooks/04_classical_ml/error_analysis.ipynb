# %% [markdown]
# # Error Analysis
#
# This notebook analyzes the misclassifications made by our models to identify edge cases and systematic failures.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Load Misclassifications

# %%
# Load the error tracking csv if it exists
error_file = '../../reports/model_benchmarks/logistic_regression_misclassifications.csv'
if os.path.exists(error_file):
    df = pd.read_csv(error_file)
    display(df.head())
else:
    print('Misclassification file not found. Ensure the evaluation script has run.')

# %% [markdown]
# ## Confusion Matrix

# %%
cm_path = '../../reports/figures/confusion_matrix.png'
if os.path.exists(cm_path):
    from IPython.display import Image
    display(Image(filename=cm_path))
else:
    print('Confusion matrix image not found.')
