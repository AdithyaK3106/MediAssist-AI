# %% [markdown]
# # Xgboost Experiment

# %% [markdown]
# ## Experimentation for xgboost

# %%
from src.models.classical_ml.predict import ClassicalInferencePipeline
pipeline = ClassicalInferencePipeline(model_name='xgboost')
results = pipeline.predict(['I have a headache and fever']) 
print(results)

# %% [markdown]
# ## Model Evaluation

# %%
import json
with open('../../models/classical/xgboost/metrics.json', 'r') as f:
    print(json.load(f))
