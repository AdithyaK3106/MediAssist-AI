# %% [markdown]
# # Logistic Regression Experiment

# %% [markdown]
# ## Experimentation for logistic_regression

# %%
from src.models.classical_ml.predict import ClassicalInferencePipeline
pipeline = ClassicalInferencePipeline(model_name='logistic_regression')
results = pipeline.predict(['I have a headache and fever']) 
print(results)

# %% [markdown]
# ## Model Evaluation

# %%
import json
with open('../../models/classical/logistic_regression/metrics.json', 'r') as f:
    print(json.load(f))
