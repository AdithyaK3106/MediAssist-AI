# %% [markdown]
# # Uncertainty Analysis
#
# This notebook evaluates how the models quantify uncertainty using entropy and top-2 gap metrics.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Review Pre-calculated Uncertainty Distributions

# %%
import glob
from IPython.display import Image, display

# Display all entropy/gap histograms generated during benchmarking
uncertainty_figures = glob.glob('../../reports/figures/uncertainty/*.png')

if uncertainty_figures:
    for fig in uncertainty_figures:
        print(f'\n--- {os.path.basename(fig)} ---')
        display(Image(filename=fig))
else:
    print('No uncertainty figures found in reports/figures/uncertainty/.')
